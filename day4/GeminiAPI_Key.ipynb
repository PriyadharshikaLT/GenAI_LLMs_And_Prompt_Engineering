# %%
pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in /usr/local/lib/python3.12/dist-packages (2.10.0)
# Collecting google-genai
#   Downloading google_genai-2.11.0-py3-none-any.whl.metadata (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.14.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.48.1 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.49.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.12.5 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.13.4)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai) (2.32.4)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai) (9.1.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai) (1.3.1)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.18)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (49.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.12.5->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (0.6.3)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.48.1->google-auth[requests]<3.0.0,>=2.48.1->google-genai) (3.0)
# Downloading google_genai-2.11.0-py3-none-any.whl (984 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.2/984.2 kB 10.3 MB/s eta 0:00:00
# Installing collected packages: google-genai
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 2.10.0
#     Uninstalling google-genai-2.10.0:
#       Successfully uninstalled google-genai-2.10.0
# Successfully installed google-genai-2.11.0

# %%
from google.colab import userdata
api_key=userdata.get('GEMINI_API_KEY')

# %%
#print(api_key)

# %%
from google import genai

client = genai.Client(api_key=api_key)

interaction = client.interactions.create(
    model="gemini-3.5-flash",
    input="Who is the Prime Minister of India?"
)
print(interaction.output_text)
# Out:
# The Prime Minister of India is **Narendra Modi**. He has been in office since May 2014.

# %%
from google import genai

client = genai.Client(api_key=api_key)

# Server-side state (recommended)
interaction1 = client.interactions.create(
    model="gemini-3.5-flash",
    input="My name is Priyadharshika",
)
print("Response 1:", interaction1.output_text)

interaction2 = client.interactions.create(
    model="gemini-3.5-flash",
    input="Tell me the count of letters in my name",
    previous_interaction_id=interaction1.id,
)
print("Response 2:", interaction2.output_text)
# Out:
# Response 1: Hello, Priyadharshika! It is wonderful to meet you. How can I help you today?
# Response 2: Your name, **Priyadharshika**, has **14** letters!

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="high",
    config=types.GenerateContentConfig(
        system_instruction="Give me a short story",
        temperature=0.3,
    ),
)
# print(response)
print(response.text)
# Out:
# At eighty stories up, the wind didn't just blow; it sang. It was a low, vibrating hum that rattled the steel cables and bit at Julian’s exposed cheeks.
#
# Below him, the city was a sprawling circuit board of yellow headlights and neon pulses. From this height, the honking taxis and screaming sirens were muted into a soft, oceanic murmur. People were nothing more than microscopic dust motes, rushing toward insignificance.
#
# Julian adjusted his grip on the twenty-foot ash-wood balancing pole. It was cold, but his palms were warm, slick with a nervous sweat he had spent thirty years learning to ignore.
#
# He looked across the abyss. Three hundred feet away, spanning the gap between the twin glass towers, was the wire. It was a silver thread, barely an inch thick, suspended in the empty air.
#
# "You don't have to do this," his technician’s voice crackled in his earpiece. "The wind shear is hitting twenty knots."
#
# Julian didn't answer. He reached up, tapped his earpiece, and switched it off. The sudden silence was absolute, save for the wind.
#
# He took a breath, filling his lungs with the thin, crisp air. Up here, the air tasted different. It tasted of ozone and clouds, untainted by the exhaust of the world below. This was the "high" he had chased his entire life—not just the physical altitude, but the sublime, terrifying clarity that came with it. Down on the pavement, life was a chaotic tangle of bills, regrets, and fractured relationships. But on the wire, life was beautifully, perfectly simple.
#
# It was binary: balance, or fall.
#
# Julian placed the ball of his right foot onto the steel cable. He felt the vibration of the wire through his thin-soled leather shoes. It was alive, humming with tension.
#
# He stepped out.
#
# The first ten steps were always the hardest. It was the transition from the safety of the concrete platform to the lawless sky. The void yawned beneath him, pulling at his gravity, whispering for him to look down. He kept his eyes locked on the red beacon of the opposite tower.
#
# Step. Slide. Breathe.
#
# At the midpoint, a sudden, violent gust of wind slammed into him from the north. The wire whipped to the left.
#
# Julian’s heart hammered against his ribs. His body reacted before his brain could. He dipped his left hip, tilting the heavy ash pole to the right to counteract the force. For three agonizing seconds, he hovered on the edge of the knife, suspended between life and the long drop.
#
# He didn't panic. In the high places, panic was a death sentence. Instead, he leaned into the wind, riding the sway of the wire like a surfer on a wave.
#
# The wire settled. Julian exhaled, a puff of white mist disappearing into the dark.
#
# He began to walk again, faster now, finding a rhythm. The fear evaporated, replaced by a profound, weightless euphoria. He felt as though he weren't walking on steel, but on the air itself, a ghost drifting between the stars and the streetlights.
#
# When his foot finally touched the solid wood of the opposite platform, a collective, distant roar rose from the streets below—the crowd, watching through binoculars, realizing he had made it.
#
# Julian stepped off the wire. His knees shook slightly as the adrenaline began to fade. He looked back at the thin silver line he had just crossed, then down at the glittering city.
#
# He was safe. He was grounded. But as he looked at the earth beneath his feet, he already felt a quiet, aching homesickness for the high.

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents="high",
    config=types.GenerateContentConfig(
        system_instruction="Give me a short story",
        temperature=0.8,
    ),
)
# print(response)
print(response.text)
# Out:
# At eighty-two stories up, the world didn’t have a sound.
#
# Leo clipped his harness to the steel rig, the carabiner clicking with a cold, solid snap. The wind at 6:00 AM was sharp, tasting of ozone and altitude. Below him, the city was a miniature model of itself—tiny headlights crawling like glowing embers through concrete canyons, still half-asleep under a blanket of blue morning fog.
#
# He stepped onto the scaffold. It swayed, just an inch or two, a gentle reminder of the drop.
#
# To most, this was a nightmare of gravity and vertigo. To Leo, it was the only place he could breathe. Down on the asphalt, life was a claustrophobic crush of noise, bills, and elbows. But up here, he was a giant.
#
# He dipped his applicator into the bucket of soapy water. *Swoosh, swoosh.* He swiped the wet sheepskin across the massive glass pane of the investment firm’s headquarters. Then, with a practiced flick of his wrist, he drew the squeegee down.
#
# *Shhhk. Shhhk.*
#
# A clean streak of morning light broke through the glass. Inside the office, the desks were empty, the computers dark. It felt like looking into a museum of human hurry, temporarily frozen in time.
#
# The sun finally breached the horizon, spilling liquid gold over the edge of the world. It caught the mist below, turning the entire city into a glowing, ethereal ocean.
#
# A shadow darted past. Leo looked up. A peregrine falcon, the true landlord of the skyscraper, had perched on a steel girder ten feet away. It preened its feathers, completely unbothered by the human hanging from a wire.
#
# Leo smiled, raising his squeegee in a silent toast. "Morning," he whispered.
#
# The wind picked up, a sudden gust that made the cables hum like a giant cello. The scaffold swung out, suspended in the empty air, before settling back against the glass. For a second, Leo’s heart did a familiar, thrilling dance in his chest. It wasn’t fear; it was the intoxicating reminder of being completely, vividly alive.
#
# He wiped the last corner of the window dry. He was high above the stress, high above the noise, hanging by a thread in the golden sky. And as he looked out at the endless horizon, he knew he was never going to take a desk job.

# %%
from google.genai import types
client = genai.Client(api_key=api_key)
response = client.models.generate_content(
    model="gemini-3.5-flash",
    contents=types.Part.from_text(text='Why is the sky blue?'),
    config=types.GenerateContentConfig(
        temperature=0,
        top_p=0.95,
        top_k=20,
        candidate_count=1,
        seed=5,
        max_output_tokens=100,
        stop_sequences=['STOP!'],
        presence_penalty=0.0,
        frequency_penalty=0.0,
    ),
)

print(response.text)
# Out:
#  white light, made

# %%
user_profile = {
    'properties': {
        'age': {
            'anyOf': [
                {'maximum': 20, 'minimum': 0, 'type': 'integer'},
                {'type': 'null'},
            ],
            'title': 'Age',
        },
        'username': {
            'description': "User's unique name",
            'title': 'Username',
            'type': 'string',
        },
    },
    'required': ['username', 'age'],
    'title': 'User Schema',
    'type': 'object',
}
client = genai.Client(api_key=api_key)
response1 = client.models.generate_content(
    model='gemini-3.5-flash',
    contents='Give me a random user profile.',
    config={
        'response_mime_type': 'application/json',
        'response_json_schema': user_profile
    },
)
print(response1.parsed)

response2 = client.models.generate_content(
    model='gemini-3.5-flash',
    contents='Give me a random user profile.',
    config={
        'response_mime_type': 'application/json',
        'response_json_schema': user_profile
    },
)
print(response2.parsed)
# Out:
# {'age': 15, 'username': 'cool_kid_99'}
# {'age': 15, 'username': 'coder_pawn'}
